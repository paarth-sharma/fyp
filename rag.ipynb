# %%
# Environment setup
from dotenv import load_dotenv
import os
import warnings
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
warnings.filterwarnings("ignore")
load_dotenv()
# Out:
# True

# %%
import faiss

from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

from langchain_text_splitters import MarkdownHeaderTextSplitter

from langchain_ollama import ChatOllama, OllamaEmbeddings

from docling.document_converter import DocumentConverter

# %% [markdown]
# ### Convert pdf document to markdown

# %%
def load_and_convert_document(file_path):
    converter = DocumentConverter()
    result = converter.convert(file_path)
    return result.document.export_to_markdown()

source = "./data/input/document_1.pdf"
markdown_content = load_and_convert_document(source)

print(markdown_content)
# Out:
# <!-- image -->
#
# THlE ARAB OIL CUTBACK AND HIGHER PRICES: .IMPLICATIONS AND REACTEONS
#
# Secret
#
# ## Secret
#
# 19 October
#
# 1973
#
# ## A. The Oil Weapon and  Its  Effects
#
# On 17 October  the Organization. f Arab  Petroleum Exporting o Countries  (OAPEC) decided to cut  oil  production.
#
# - -Production  will  be reduced by  not less  than 5% a month until  an  Israeli ithdrawal from , ccupied territories w o is completed and  the "legal  rights"  of the Palestinians e ar restored;
# - -The Arab countries  lso  promised  to  maintain il eliveries a o d to "friendly"  ountries hat ive  Arabs "effective  aterial c t g m help"; nd a
# - --Threatened a  total mbargo  of countries hat  used their e t armed  forces  to  aid Israel.
#
# Many  parts f  the  statement ere left eliberately  gue in  brder  to o w d va allow  each Arab  country  a degree  of  freedom to  act  according o ts  wn t i o best  interests.  is  ambiguity Th -similar o that f  OPEC t o decisions  n  the i past -is  intended o  give  the APEC t O agreement  greater  urability    giving d by each  country  greater  flexibility.   of the states re obliged  to cut All a production y b 5% a month,  but  the  way  is  open for  some to  make  larger cuts. The Arabs did  not  define hose  "friendly"  ountries  hat  ill ontinue t c t w c to receive  normal imports  from the  Arab World. They  probably  will  cut back shipments  to neutral tates  uch as the  United Kingdom  and Japan s s and may  cut back shipments  to  such states  s  France  and Italy hat re a t a "tilting"  heir  neutrality  oward  the Arabs. In  any  event,  the final t t interpretation    the definition    left  o  the  individual  roducing ountry. f is t p c
#
# At least  in the first  onths,  the  Arab monthly production utback m c will  probably  be between 5%  and  10%,  but  closer  to  the 5% rate.  audi S Arabia  has reportedly  lready  cut  current  roduction  y 10%.  Some  other a p b countries  such as  Iraq, hich is  unable  to  export ost of ts  roduction -w m i p because  of  the  closure f  eastern  editerranean orts o M p -may  make  a  virtue of  necessity  nd  make very  large nitial  ts.  n  all-Arab  utback f etween a i cu A c o b 5%  and 10%  would represent loss f  between  one  million nd  two million a o a barrels er day (b/d). p
#
# Several countries,  ncluding  Libya, Abu i Dhabi, Kuwait, and  Saudi Arabia,  have  either nnounced or threatened   total mbargo against he a a e t United States. However, the  United States receives only  about 1.6 million  b/d  of  Arab oil including  roducts  efined  n  Europe and the ( p r i
#
# Caribbean). hus, even if  the  embargo  were  effective, e  effect  n  the T th o United States  would  be relatively all,  and,  after he first  onth, the sm t m brunt  of  the  cutback  would fall n Europe and Japan.  Moreover, the  US o companies  that roduce  most Middle East  oil ight  be able  to  shift  upplies p m s among  themselves  to  avoid the  embargo.  The companies  .would, f  course, o hesitate  o  do this or  fear f eopardizing eir  elations  th  the  producing t f o j th r wi countries  s well as with Western Europe and Japan. a
#
# It  seems inevitable at estern Europe and Japan  will  bear  the  brunt th W of  the  progressive  utbacks.  estern Europe is  dependent  on Arab oil  for c W 70%  of  its onsumption,  and Japan depends  on the  Arabs for  40%  of  its c supply. he  producer  states  ecognize hat t s  "unjust" o  punish  Europe T r t i i t and Japan  more severely  han  the  United  States, t  see  no other  lternative. t bu a The  Saudis have  informed representatives  the major West  European of nations hat hey  will e xpected  to  pressure he  United  States. ey have t t t e t Th also  suggested  to the  Japanese  that hey  make  a statement  efore  the  UN t b General Assembly  to the  effect hat apan  desires n early  settlement  o t J a t the  war  and  that  it  supports he  Arab  position. t
#
# From  the point  of  view of  United  States ulnerability, s  Ierhaps v iti fortunate  hat  this articular  isis  ccurred  now  rather han  a t p cr o t few years hence.  It  had been predicted hat  we would be importing  early  million t n 5 barrels  er  day of rab oil r  21%-22% p A o of  our  consumption  by 1980.  With this evel  of  exports n Arab cutoff  ould severely ffect ur  economy. l a w a o Even now  there re  domestic  as  well  as  foreign ressures  or olicy  hanges a p f p c as a result f the  current utoff.  any event,  the  rapid  increase n the o c In i price  of  imported  oil  should dampen our consumption and  make  other domestic  energy sources  more  attractive,  r  example oil  from Colorado fo shales  and  coal  gasification.
#
# Although  the West  European countries re attempting o form  a a t common position  egarding he  oil utback, ivision  endencies  ay  prove r t c d t m too strong.  oint  contingency  plans  exist, ut,  because  of  the  different J b countries'  ifferent  iews of  their  wn d v o advantage, he  plans  may  not  be t used efectively. dividual  ountries  lso  have developed  plans  for ealing In c a d with a crisis  n  a national  asis. ome  reportedly  re updating ationing o b S a r systems  worked out  during  earlier ises  nd have  stocks f ationing oks cr a o r bo ready  for istribution. the  same time,   few European  countries, tably d At a no France,  still  ntertain  opes that he  Arab oil  production  utback  will ot e h t c n apply to them.
#
# The immediate  impact  from war damage  and production utbacks  ill c w vary considerably mong  EC a members. The  shutdown of  three  eastern Mediterranean  pipelines  lready  has dropped Italy's  l  imports  by some a oi
#
# SECRET
#
# 24% and France's y  14%,  while affecting  ther embers' imports  only b o m moderately  or  not at all.  Because of the large difference  n shipping i distances, those  nations  uch as West Germany  that epend most heavily s d on North African  oil  will  feel  the pinch of  a  production utback  much c sooner than those  such as the  Benelux countries  hat epend on Persian t d Gulf  .supplies  see the  table).  taly lready  has imposed an  embargo  on ( I a refined il exports utside  the EC o o -a move  detrimental  o  US  supplies t that ay  be emulated  by other  ommunity  members if he  supply  situation m C t worsens.
#
# Over the next few  months,  the impact of reduced  oil  imports  will be partly itigated  by  reserve  stocks  maintained  by the  EC  nations.  ll m A have  about  two-month  supply  on hand,  and  France  reportedly  as  a 90-day a h reserve. Arab  oil,  however, accounts  for  between 63%  and 78%  of  EC members' oil  imports and  a  similar share  of  their  otal  onsumption.  As t c a result, a 5%-10%  cumulative onthly  reduction  n  production  y the  Arab m i b states, together  with already  interrupted peline eliveries, uld  soon pi d wo force  EC nations to  draw heavily n riserve  tocks.  f urrent  onsumption o s I c c levels were maintained, these reserves  ight be depleted ithin  six  months, m w and  total  available supplies could be  reduced to one-half  of normal. Conservation measures could delay the depletion f reserves y at  most o b another  few  months.
#
# EC  Nations' ependence D on Arab Oil, y Source,  1972 b
#
# |                 | Percent  of  Total  Imports                     | Percent  of  Total  Imports   | Percent  of  Total  Imports                  | Percent  of  Total  Imports   |
# |-----------------|-------------------------------------------------|-------------------------------|----------------------------------------------|-------------------------------|
# |                 | Persian  Gulf  by Pipelines  (Now  Inoperative) | North African  by Tanker      | Persian ulf  G by Tanker  (35-day  Delivery) | Total Arab                    |
# |                 |                                                 | (7-day  Delivery)             |                                              | Crude                         |
# | Italy           | 24                                              | 19                            | 26                                           | 69                            |
# | France          | 14                                              | 18                            | 46                                           | 78                            |
# | United  Kingdom | 5                                               | 15                            | 48                                           | 68                            |
# | West Germany    | 4                                               | .39                           | 29                                           | 72                            |
# | Benelux         | 6                                               | 4                             | 53                                           | 63                            |
# | Denmark         | ....                                            | 1                             | 66                                           | 67                            |
#
# ## The  Effects of a 5% Cutback Over Time
#
# The following  graphs  show  the cumulative ffects  f  a five ercent 5 e o p all-Arab  production utback on  the United States,  estern Europe,  and c W Japan under different  onditions. c
#
# -
#
# 3
#
# ## SECRET
#
# Clearly  such a  production utback,  if  it  persisted  or  a  number of c f months,  would require ome  belt  tightening. t,  the analysis  hows that s Bu s by moderate belt ightening d  drawing  down existing ocks f  petroleum, t an st o we  can avoid a  serious risis  his inter. his  posture  is  illustrated t c t w T bes by Figure  5, which shows that a 5% reduction  n  consumption  in  the  United i States nd a  10%  reduction  n  consumption  in Western Europe and Japan, a i together ith stock drawdowns and a 300,000 barrel er day combined, w p surge  in  the  United  States  nd  Venezuelan  production, en  Western  Europe a ev and Japan would not face a real  crisis  or  some  time. f
#
# This  does not  mean  that here ould not  be dislocations  d  regional t w an problems  in the  United  States  s well  as  in  Western Europe.  For  example, a heating  il roblems  in he nited  States  ast oast ould worsen  somewhat. o p t U e c w
#
# Moreover,  the  United  States ould come under  considerable  ressure w p to  share  to  some  extent ith  Western Europe and Japan if hey  should w t come  to  believe hat heir  upplies  ere to  be cut  back for everal onths. t t s w s m In this vent  our own  belt  tightening  ight have to.  e greater  han  the e m b t 5% shown  in the illustration.
#
# 4
#
# ## Figure  1
#
# Time  Paths  of  Consumption, Under No  Sharing, No  Stock  Withdrawals,  No  Rationing,  nd a Five a Percent  per  Month  Cutback  in OAPEC Exports
#
# ## Consumption in Million arrels  er  Day B P
#
# <!-- image -->
#
# Time Paths  of  Consumption, Under Consumption Sharing,  No  Stock  Withdrawals,  No  Rationing, nd a a Five  Percent er  Month  Cutback  in OAPEC p Exports
#
# <!-- image -->
#
# Time  Paths of Consumption, Under Import  Sharing, No  Stock  Withdrawals,  No  Rationing,  nd a Five a Percent utback per  Mbnth  in OAPEC C Exports
#
# <!-- image -->
#
# ## Figure  4
#
# Time  Paths  of  Consumption, Under No  Sharing, tock  Withdrawals S to  Cover Import  Losses  Until tocks  are  Depleted, o S N Rationing, nd a Five  Percent' r  Month  Cutback a pe in OAPEC Exports
#
# <!-- image -->
#
# <!-- image -->
#
# Timre Paths  of  Consumption, Under No  Sharing,  Stock Withdrawals  to  Cover Inport osses  Until tocks  are L S Depleted,  300,000  Barrels  er  Day  Surge  in US  ProP duction, ive  Percent eduction  in US  Consumption, F R Ten Percent  Reduction  in European and Japanese  Consumption,  and a Five  Percent er  Month  Cutback in p OAPEC Exports
#
# Consumption in Million arrels  er  Day B P
#
# <!-- image -->
#
# <!-- image -->
#
# ## Figure  5
#
# ## B; The  Impact of Increased  Oil Prices
#
# The increase  n oil  prices ill  be felt rimarily  n the  United  States, i w p i Japan,  and Western Europe.  The oil  import  bills  f  the  United  States  nd o a Japan will  each increase y about  S3  billion, ile the  additional st o b wh co t Western Europe will approach  S8  billion.  is  assumes  that eliveries om Th d fr the Gulf  will  continue as  scheduled  prior  to the announcement  of production imitations. l
#
# - -The oil  price ise ill urn n expected   I billion  r  so  1974 r w t a S o US  trade  surplus nto  a roughly $2 billion  eficit i d
# - The  Canadian trade  balance  will  be virtually  naffected u because Canadian oil  imports  are  roughly  equal  to  exports
# - Japan,  which imports  about  43%  of  its il  from the  Arab o countries,  ill  have  a  1974  surplus  of  about  $3 w billion, compared with a previous  estimate f $6 billion. o
# - -The  West  Germans  will pay  an  additional  ost  of about c $1.8 billion  the  highest  in Europe --but  they  will  feel the  least ardship ecause  their 974 trade  surplus ill  be h b 1 w on the order  of  $8  billion.
# - -Petroleum  imports ill  push  the  UK  trade eficit om  about w d fr $3.5 billion o  almost  $5 billion. t
# - -The OPEC action  will  add $1.5 billion  o the oil  import t bill f  both  France  and Italy. e price ncreases ll educe o Th i wi r the  French  surplus  o  near  zero. taly's  all  deficit   1973 t I sm in was  expected  to  narrow further  ut  should  now  be in the b $1.5 billion-S2  illion  ange. b r
#
# Some  of  the impact  of  higher  oil rices n the consuming countries p i will  be offset y  greater epatriation    oil  company  profits  nd larger b r of a exports  to  the  producers,  enerated y their  reater xport  income.  Only g b g e part  of the  worldwide producer  revenue increases f o $15 billion  ill  be w spent, owever.  The 1974 oil  revenues  of  Saudi  Arabia, bu  Dhabi,  Qatar, h A and Kuwait will  approach  the  amounts  recently  stimated  or  1980.  These e f countries  ave only limited bsorptive apacities. h a c
#
# Although the trade  balances  of the oil  importers ill deteriorate w sharply, he  impact on their omestic  economies will  probably  be slight. t d Oil imports  do not  compete with  domestic  production  o there hould  be s s no initial fsetting ss  in  jobs. he consuming countries' n-petroleum of lo T no trade  and production ill  essentially   the  same  as  before  the oil  price w be
#
# 5
#
# increase.  oreover,  the  sharp  rise n crude  oil rices  hould  not  significantly M i p s increase he price  of  finished oods. t g
#
# The use to  which the  oil  producers ut  their  eserves ould  have an p r c appreciable  mpact  on the  international hange  rate ystem  and,  through i exc s the  exchange system,ultimately    the  volume  of  exports nd imports. on a If,  or xample,  the  producers  ecide  to-hold  ost of heir  ncreased  eceipts f e d m t i r in  dollars, he dollar  will strengthen  in exchange  markets.  A t dollar appreciation  eans more expensive m -and therefore  educed r -US exports. In effect,  he oil  producers  will  be converting heir  rade  surpluses  ith t t t w other  consumers  into rade urpluses  ith  the  United  States;  r, n  another t s w o i view,  the  US  trade  account  with Japan,  Canada, and Western Europe will deteriorate   the  amount 'of he  increase n their il  import  bills. by t i o
#
# As the  oil roducers'  eserves  ncrease,  heir  hreat  o  exchange  markets p r i t t t will  also  increase.  he Arab oil  states  lready ave enough liquid oreign T a h f assets -around SS-S7  billion    to  temporarily  isrupt  urrency  markets. ' d c Although there  is  no  evid'ence f  any substantial llar ales  during  the o do s current risis, d an attack  n the  dollar  ould result  the  depreciation c an o w in of the  Arabs'  own reserve  holding, t  is not  inconceivable  hat i t -if  the political  d  military  ituation  comes increasingly acceptable  o  them an s be un t -the Arab leadership  ould move  against  the  dollar.  n  Thursday,  Libya w O publicly  called for  concerted rab dollar ales  and  withdrawal f  deposits A s o from US  banks.
#
# 6
#
# ## SECRET
#
# -
#
# ## C. Foreign  Reaction
#
# Western Europe
#
# There is  very little e  West  Europeans  can do in the  near  term to th get  their  il  deliveries ck to  strength. ey  will, f course, ontinue o o ba Th o c t distance  hemselves  from Washington's resent iddle Eastern olicy t p M p -in speeches,  in UN  votes, nd in the  denial  of  overflight d refueling  ights a an r for  US military aircraft. But no European leader xpects uch behavior o e s t cause Washington to  rethink ts osition r  entirely  o  save  Europe from i p o t the effects  f  the  oil  embargo. Indeed,  the  West  Europeans  probably  are o overly  conscious f  their  mpotence  to  influence  he  present  ituation; y o i t s the are more inclined  o  "keep their  eads  low"  in the  hope of  warding  off t h still  reater g threats o their nergy supply. t e
#
# At the  moment, the  West Europeans  are  eager  to  discuss il  problems o with the  United  States,  oping  naturally  hat he  United  States  ill gree h t t w a to  share upplies  and  shortages).  t  if  uch  agreements re  not orthcoming s ( Bu s a f from  Washington and  if  oil  shortages egin to bite  severely b -the Europeans  would try  at  least  o  keep all he  oil hey  can  get  for hemselves t t t t by reducing r  eliminating  heir  xports f  refined  il o  the nited o t e o o t U States. In such a scramble,  they  would  be more  likely o  act  unilaterally  an t th on  a joint European-wide basis.
#
# There  is  some inconsistency tween the  European desire o  minimize be t association with  US  political  licy n  the  Middle East  crisis  nd  European po i a awareness that  some  form of  cooperation rrangement or  coping  with  oil a f shortage must necessarily  involve  US-European conversation. his T inconsistency   both  real  and apparent.  he Europeans  will  try  to  resolve is T it nsofar  s they  can, by working  for  quiet alks ithin ECD i a t w O forum on oil atters,  hile  avoiding olitical  itiatives  ess nd  until e  time  seems m w p in unl a th ripe  for  a  mediation  role  that ould  not  alienate  he Arabs. w t
#
# Over the  longer un,  the  present xperience  ill  further courage  the r e w en West  Europeans  to  decrease heir t reliance  on the  major  oil ompanies  and c to  develop  instead  heir  wn  arrangements ith  oil roducing overnments. t o w p g They would focus  on offers  f  government-to-government  greements  that o a would involve  European technical  assistance  in  return for supply commitments,  and possibly rade  preferences  or  oil  producing tates. t f s An obvious  side  effect  f  such  a policy ould be  lessened  uropean  willingness o w E to  join n consumer cooperation  chemes on terms  favorable o  the  United i s t States or -depending  on  US-Arab  relations  the postwar  world in -be associated with the  United  States  n oil ooperation  chemes on any terms i c s at  all.
#
# 7
#
# ## SECRET
#
# I
#
# Japan
#
# The Japanese  have always sought  to  avoid taking sides  in contentious situations volving  Middle East oil.  In the last  year,  the  Japanese  have in refused  to  join n oil  consumers  organization, r ear  of  antagonizing  he a fo f t oil  producers  in OPEC. There has been an ongoing debate  in Japan for some  time over the merits  of  multilateral  rsus  go it  alone  approaches ve to  assuring il  supplies. o
#
# Japan's  olicy n  regard  to  the  present etroleum upply  situation  sts p i p s re almost entirely  n the  hope  that  the current iddle  East crisis  an be o M c defused  before  severe  sanctions  re  enacted  by the  Arabs.  Tokyo is  being a urged by the  Arab states,  ith  Saudi  Arabia  taking  the  lead,  to  issue  an w official atement upporting  he  Arab position  n  the  current  onflict.  e st s t i c Th Arabs have avoided  accompanying such requests  ith  threats  f  a serious w o disruption  n  the  flow of  oil  to  Japan. evertheless, e  implied hreat  f i N th t o economic blackmail  has  not  been lost n the  Japanese. he Japanese  are o T extremely  reluctant  o  abandon their eutral  osition  n the  Middle East t n p o primarily  ecause  of  the  serious mpact  such  a step ould b i w have onlelations with the United States,  n particular  ith regard  to existing  lans  for i w p bilateral  ooperation  in the field  of energy-petroleum  sharing. oreign c F Minister hira, n 19  October,  ought  to  sidestep  n  Arab  request  or irect O o s a f d political support  when  he told  a group of  Arab envoys that apan favors J settlement  hrough  the  United  Nations nd noted  that apan  supported he t a J t 1967 Security  Council resolution  alling  for Israeli ithdrawal  from c w occupied  Arab  territory.
#
# Tokyo's political  ightrope alk  will have difficulty rviving  an t w su indefinite olongation  r  heightening  f  Arab pressure.  f  backed to the pr o o I wall  by credible  rab threats  f  a cut  off f  oil,  he  Japanese ill robably A o o t w p give in.  As  a contingency  measure,  the Japanese  Government  is  already studying rafts  f  a statement upporting  he  Arab position  hat ould  be d o s t t c used  in such a forum as the  UN  General  Assembly.  But Japan  would first make  a last itch ffort  o  secure ssistance  rom the  United  States  n the d e t a f i form of  diversion f some  US o oil  supplies o  Japanese  needs. t
#
# 8"
#
# ## SECRET
#
# <!-- image -->
#
# ## ANNEX
#
# ## Selected  Tables
#
# ## SECRET
#
# <!-- image -->
#
# <!-- image -->
#
# No  Objection
#
# <!-- image -->
#
# | qTo               | :  Cc:us:-  tin   | Crx:cic Pcduc.-  t cn   | otal  I:-orts   | Total  MAb   | Saoti  Arahin   | Abu  Dh.bi   | Ktwait   | Ira          | Libya   | Al-  seria   | Other  Ar.u   | Irr   | Vr.'-  .'t:^   | Irido-   |       | Ni- csia  Crr.a  ceria  C!^^rs   |       |
# |-------------------|-------------------|-------------------------|-----------------|--------------|-----------------|--------------|----------|--------------|---------|--------------|---------------|-------|----------------|----------|-------|----------------------------------|-------|
# | .it:  Statcs  %   | 17,300            | 10,900                  | 6,300           | 1,600        | 600             | 150          | 150      | 50           | 350     | 150          | 150           | 400   | 2,000          | 250      | 1,100 | 550                              | 4G0   |
# | of  Cons-.p- tion | 100               | 63.0                    | 36.4            | 9,2          | 3.5             | 0.9          | 0.9      | 0.3          | 2       | 0.9          | 0.9           | 2.3   | 11.6           | 1.4      | 6.4   | 3.2                              | 2.3   |
# | c:  r             | .15,500           | 400                     | 10,000bf 11,300 |              | 4,350           | 600          |          | 1,750  1,300 | 1,700.- | 750          | 850           | 1,900 | 500            | Nc3l.    | 0     | 1,250                            | 1,050 |
# | icn               | 100.              | 2.6                     | 103             | 72.9         | 28.1            | 3.9          | 11.3     | 0.4          | 11.0    | 4.8          | 5.5           | 12.3  | 3.2            | Nexjl.   | 0     | 8.1                              | .6.   |
# | Ja                | 5,400             | NC-1.                   | 5,400           | . 2,300      | 1,250           | 300          | 650      | 50           | Nogl.   | 0            | p0            | 2,050 | Na&lt;jl.         | 900      | 0     | Nc.jl.                           | 15C   |
# | tion              | 100               | Nc'jl.                  | 100             | 42.6         | 23.2            | 5.6          | 12.0     | 0.9          | N1f1.   | C            | 0.9           | 38.0  | Nr:.'l.        | 16.7     | 0     | Nce21.                           | 2.    |
# | c.?  h  t         | 1,750             | 1,850                   | 900             | 150 -.       | 50              | 50           | Ne31.    | Ncgl.        | 50      | 0            | NcI.          | 150   | 450            | 0        | 0     | 100.                             | 5(    |
# | of  C:::7.:gy in  | ,  . 100          | 106                     | 51.4.           | . .          | 2.9             | 2.9          | N11.     | Ntvfl.       | 2.9     | 0            | No.jl.        | 8.6   | 25.7           | 0        | 0     | 5.7                              | 2.    |
# | S=-'metal         | 31,90             | 33,10                   |                 | 15,300       |                 |              | 2,550    |              | 2,100   | 900          | 1,010         |       | 2,5  ?         | 0        |       | 1,900                            | 1,r0  |
# | lofG:=            |                   |                         | f(,00           |              | 6,200           | 1,100        |          | 1,400        |         |              | -             | 4,,00 |                |          | 1,10  |                                  |       |
# | CC:.ijs;t         | Arca  9,850       | 9,300                   | 500             | 400          | Ncejl.          | Negl.        | 0        | 200          | 100     | 50           | 50            | 100   | 0              | 0        | 0     | 0                                | .0    |
# | 9  ofto&gt;.. ticn   | 1CO               | 94.4                    | 5.1             | 4.1          | Neal            |              | 0        | 2.0          | 1.0     | 0.5          | 0.5           | 1.0   | 0              |          |       |                                  |       |
# | G  :rs            |                   |                         |                 |              |                 | Ne';1.       |          |              |         |              |               |       |                | 0        | 0     | 0                                | 0     |
# |                   | 7,200             | 34,550                  | 4,900           | 2,850        | 1,750           | 50           | 550      | 300          | 0       | 150          | 50            | 1,100 | 450            | 100      | 0     | 100                              | 30    |
# | :ion              | 100  37,l         | 480                     | 68.1  1         | 39.6         | 24.3            | 0.7          | 7.6      | 4.2          | 0       | 2.1          | 0.7           | 15.3  | 6.2            | 1.4      | 0     | 1.4                              | 4.    |
# |                   |                   | 3.70.  c\_/ 4/O          |                 | !Rf2         | 1,0             | \_1,'00       | 3300     | .1t'00.      | g200    | .J300        | 1150          | ,700  | 3,400          | 1,250    | 1,J00 | 7JC00                            | 1,9'  |
#
# - a.  T. on Ji t a:.3  i%!m::  ha:1n,  i.e.,  fined td:cts  mcn errort  .nir...,  e  tr  'i re p fr ar c .) to rce o' c:od. : ei'a ^ y.'..y a". ,r.for  1973 c:I .. :ntre itlor d frmn 1oint in time c:ir.at:. 1'or elmilc, US det:ner.ce on bAcc oil : ic.c:::  egh ."  y c r.:.y 2 million /d  in 0:.'sac*. b
#
# n
#
# - C.b. 1:.ta:n :.r.g' l  ?:o;:;.: L' oi co  ::e tion  ccou:;  it errorts. ant3ial ntities    oil ut;ide  irote. w p b cut qu of o 1
# - c. I::.-:s US pred:eion of  natural ;:s  iquitas  1.7  million l oi b/d.
#
# 1' u t 73
#
# No  Objection o Declassification 09/04/02:  NLN-H-92-3-7-1 T 20
#
# <!-- image -->
#
# <!-- image -->
#
# No  Objection  To  Declassification  09/04/02 : LN-H-92-3-7-1 20
#
# N
#
# Oil ' ade r +/, 1973
#
# <!-- image -->
#
# -ousand  Darrel-em r:
#
# |                | c  s-     | Dc::cstic- Produ~c-   |        | Total  Total  t-ort~   | rb     | Saly3i        | M~u  D i  0b   | Xwait   | Irag         | Sra  va  Lib   | Al-  qria   | Other   |       | Vce - IrM  .us:a   | Incb-   | crab  r.Sia czn?'  a   | C'ria   | CL  rs   |
# |----------------|-----------|-----------------------|--------|------------------------|--------|---------------|----------------|---------|--------------|----------------|-------------|---------|-------|--------------------|---------|------------------------|---------|----------|
# | 3  c:  States  | 17,300    | 10,900                | 6,300  |                        | 1,000  | G00           | 150            | 150     | 50           | 350            | 150         | 150     | 400   | 2,000              | 250     | 1,100                  | 550     | 400      |
# | 'en            | 100       | 63.0                  | 36.4   |                        | 9;2    | 3.5           | 0.9            | 0.9     | 0.3          | 2              | 0.9         | 0.9     | 2.3   | 11.6               | 1.4     | 6.4                    | 3.2     | 2.3      |
# | Fcrn  r        | 15,500    | 400                   |        | 16,000f 11,300         |        | 4,350         | 600            | 1,750   | 1,300        | 1,700,-        | 750         | 850     | 1,900 | 500                | Nc31.   | 0                      | 1,250   | 1,050    |
# | tic:           | 100.      | 2.6                   | 103    | 72.9                   |        | 28.1          | 3.9            | 11.3    | 8.4          | 11.0           | 4.8         | 5.5     | 12.3  | 3.2                | Ncgl.   | 0                      | 8.1     | .6.8     |
# | n              | 5,400     | Ne31.                 |        | 5,400  .               | 2,300  | 1,250         | 300            | 650     | 50           | Nogl.          | 0           | 50,     | 2,050 | Nrjl.              | 900     | 0                      | Ncgl.   | 150      |
# | S  Cion        | 100       | - gl.                 | ICO    |                        | 42.6   | 23.2          | 5.6            | 12.0    | 0.9          | N J1l.         | C           | 0.9     | 39.0  | NC'.               | 10.7    | 0                      | Neg.    | 2.8      |
# |                | a  1,750  | 1,050                 |        | 900                    | 150-   | 50            | 50             |         | Nc'Jl. Ncgl. | 50             | 0           | NlC1.   | 150   | 450                | 0       | 0                      | 100,    | 50       |
# | o:  coa  car   | 100       |                       | 106    | 51.4.                  | 8.6    | 2.9           | 2.9            |         | Nall. NorjI. | 2.9            | 0           | NeJ1.   | 8.6   | 25.7               | 0       | 0                      | 5.7     | 2.9      |
# | w.ut.-t        | 37,?50    |                       | 13,150 | .n,00                  | 1t,300 | 6,250         | 1,100          | 2,550   | 1,400        | 2,100          | 900         | 1,050   | 4,500 | 2,90               | 15,10   | 1100                   | 1,900   | 1,50     |
# | of  Gra T (don | 100       |                       | 32.9   | 71.G                   | 38.3   | 15.6          | 2.             | 6.4     | 3.5          | 5.3            | 2.2         | 2.6     | 11.3  | 7.4                | 2.9     | 2.8                    | 4.8     | 4.1      |
# | : ni;t  rca  A | 9,850     | 9,300                 |        | 500                    | 400    | Ncal.         | N(g1.          | 0       | 200          | 100            | 50          | 50      | 100   | 0                  | 0       | 0                      | 0       | .0       |
# | of  Gr:&gt; Len   | 100       | 94.4                  |        | 5.1                    | 4.1    | Nal           | Ngl.           | 0       | 2.0          | 1.0            | 0.5         | 0.5     | 1.0   | 0                  | 0       | 0                      | 0       | 0        |
# |                | 7,200     | 34,550                |        |                        |        |               | 50             | 550     |              | 0              | 150         | 50      | 1,100 | 450                | 100     | 0                      | 100     | 300      |
# | :Tuin          | 100       | 480                   |        | 4,900                  | 2,850  | 1,750         |                |         | 300          |                |             |         |       |                    |         |                        |         |          |
# |                |           |                       |        | G8.1                   | 39.6   | 24.3          | 0.7            | 7.6     | 4.2          | 0              | 2.1         | 0.7     | 15.3  | 6.2                | 1.4     | 0                      | 1.4     |          |
# |                | 0i  37.00 | 57,n00                | f      | 7,00n0                 | .I..   | Fl,000  1,150 |                | 3,300   | 1,00         | &amp;2O            | 1,300       | 1,170   | 5,700 | 1,400  ,..90       | 1,250   | 1.100                  | 2v.C    |          |
#
# - 2u .. \_ --
# - a. .-I all. r : 5:t~3iir2tb:i~ i.e., tinal  u~ccU1 f1:t ro rt c.3rt 170.51 cltir' r  t.:i::".1.  ::O  of a :.. c cCo. 3. a. ."r y for 1573 "1 ..or  ,iifocr rog,  joint  1%  Uve  cl~ar; f i. 'or  Cza:r1, CG a 2:c.o on AC. , oil  .:\_ h rrc~;c~L ' Gre , "' "y r..:My  r.ill 2 icn b/. in .
# - b.  -: -":n ..t's CC oil  coxcd :: c:--ptiCn  catw:c  it cjgort:  uBntianLl bc : cuantitic of oil ouU:ide luroIe.
# - c. I :-.  5  padc:d~ on of  nr.ccal  jas  iquid::   1.7  mtillion  /d.U , l of b
#
# 15 Oet 73
#
# No  Objection  To-Declassification  09/04/02: NLN-H-92-3-7-1 20
#
# Economics of  the Persian Gulf OPECa/ Price Increase 16  October 1973
#
# ($/barrel)
#
# -
#
# | Company                                                                      | New  Demand            | Percent of Increase   |
# |------------------------------------------------------------------------------|------------------------|-----------------------|
# | 1.  Posted  Priceb/(Saudi  Arabian Light  340)                               | 3.011  5.11            | 69.7                  |
# | 2.  Royalty  (12k%  of  1.)                                                  | .376  .64              |                       |
# | Production  Cost                                                             | .10                    |                       |
# | 3.                                                                           | .10                    |                       |
# | 4.  Tax  Reference  "Profit"  1-(2+3)                                        | 2.535  4.37            |                       |
# | Tax  (55%  of  4)                                                            | 1.394  2.40            |                       |
# | 5.  6.  Government  Revenue  (2+5)                                           | 1.77  3.04             | 71.8                  |
# | 7.  Cost  to  Oil  Company  (3+6)-                                           | i.87  3.14             | 67.9                  |
# | 8.  Estimated  Oil  Company  Profit                                          | .35  .35               |                       |
# | 9.  Estimated  Sales  Price  (fob) (7+8)                                     | 2.22  3.49             | 57.2                  |
# | 10  stimated  Transportation Costc/  (to  US  Gulf  Coast)                   | 1.48  1.48             |                       |
# | 1..  US  Import  Duty                                                        | .105  .105             |                       |
# | Estimated  Sales  Price  (cif, US  Gulf  Coast)                              | 3.805                  |                       |
# | 12.                                                                          | 5.075                  | 33.4                  |
# | Government  Owned  Crude  Oil  (25%)  of                                     |                        | 17.0                  |
# | Oil  Company  Purchases  Government-Owned  (22.5%)  . Third  Parties  (2.5%) | 2.30  3.65  3.12  3.65 | 58.7                  |
# | Government  Oil  Sales  to                                                   |                        |                       |
#
# - b. Posted price and tax reference price are synonymous terms.
# - c. Calculation based on  tanker rates of  Worldscale 100  which is a representative average, although spot tanker rates are currently much hi her;they account for only a  small fraction of  the oil being trans-
#
# <!-- image -->
#
# a
#
# *
#
# The  shutdo-:n f the  three astern  editcrranean ipelines o e M p Wwhich mainly serve  southern urope has reduced  Europe's  oil E supplies by  about 2  million b/d. Based on  very limited infornation, the following is our best estimate of the destination of crude  oil rom the  closed  pipelines: f
#
# | Destination                 | Volume  (b/d)   |
# |-----------------------------|-----------------|
# | Western Europe              | 1,700,000       |
# | Italy  -                    | 600,000         |
# | France                      | 375,000         |
# | Benelux                     | 150,000         |
# | United  Kingdom             | 100,000         |
# | Greece                      | 100,000         |
# | West  Germany               | 75,000          |
# | Spain                       | 50,000          |
# | Portugal                    | 50,000          |
# | Turkey                      | 50,000          |
# | Austria                     | 50,000          |
# | Others  and                 |                 |
# | Unidentified Western Europe | 100,000         |
# | Cor.munist  countries       | 200,000 50,000  |
# | Romania  Bulgaria           | 50,000          |
# | USSR                        | 50,000          |
# | Other Communist countries   | 50,000          |
# | Other Countries             |                 |
# |                             | 100,000         |
# | TOTAL                       | 2,000,000       |
#
# .
#
# CIA/OSR 18  Oct 73

# %% [markdown]
# ### Split markdown into chunks to feed the database

# %%
def get_markdown_splits(markdown_content):
    headers_to_split_on = [("#", "Header 1"), ("##", "Header 2"), ("###", "Header 3")]
    markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on, strip_headers=False)
    return markdown_splitter.split_text(markdown_content)


chunks = get_markdown_splits(markdown_content)

print(chunks[13].page_content)
# Out:
# ## ANNEX

# %% [markdown]
# ### making embeddings and vector store settings

# %%
def setup_vector_store(chunks):
    embeddings = OllamaEmbeddings(model='nomic-embed-text', base_url="http://localhost:11434")
    single_vector = embeddings.embed_query("this is some text data")
    index = faiss.IndexFlatL2(len(single_vector))
    vector_store = FAISS(
        embedding_function=embeddings,
        index=index,
        docstore=InMemoryDocstore(),
        index_to_docstore_id={}
    )
    vector_store.add_documents(documents=chunks)
    return vector_store

# %%
vector_store = setup_vector_store(chunks)
# Setup retriever
retriever = vector_store.as_retriever(search_type="mmr", search_kwargs={'k': 3})

# %%
vector_store.index.ntotal, len(chunks)
# Out:
# (16, 16)

# %%
docs = retriever.invoke('What were 5 effects of the arabic oil cutback and higher prices?')

# %% [markdown]
# ### Format documents for RAG

# %%
def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])

content = format_docs(docs)

print(content)
# Out:
# <!-- image -->
# THlE ARAB OIL CUTBACK AND HIGHER PRICES: .IMPLICATIONS AND REACTEONS
# Secret
#
# ## The  Effects of a 5% Cutback Over Time
# The following  graphs  show  the cumulative ffects  f  a five ercent 5 e o p all-Arab  production utback on  the United States,  estern Europe,  and c W Japan under different  onditions. c
# -
# 3
#
# ## B; The  Impact of Increased  Oil Prices
# The increase  n oil  prices ill  be felt rimarily  n the  United  States, i w p i Japan,  and Western Europe.  The oil  import  bills  f  the  United  States  nd o a Japan will  each increase y about  S3  billion, ile the  additional st o b wh co t Western Europe will approach  S8  billion.  is  assumes  that eliveries om Th d fr the Gulf  will  continue as  scheduled  prior  to the announcement  of production imitations. l
# - -The oil  price ise ill urn n expected   I billion  r  so  1974 r w t a S o US  trade  surplus nto  a roughly $2 billion  eficit i d
# - The  Canadian trade  balance  will  be virtually  naffected u because Canadian oil  imports  are  roughly  equal  to  exports
# - Japan,  which imports  about  43%  of  its il  from the  Arab o countries,  ill  have  a  1974  surplus  of  about  $3 w billion, compared with a previous  estimate f $6 billion. o
# - -The  West  Germans  will pay  an  additional  ost  of about c $1.8 billion  the  highest  in Europe --but  they  will  feel the  least ardship ecause  their 974 trade  surplus ill  be h b 1 w on the order  of  $8  billion.
# - -Petroleum  imports ill  push  the  UK  trade eficit om  about w d fr $3.5 billion o  almost  $5 billion. t
# - -The OPEC action  will  add $1.5 billion  o the oil  import t bill f  both  France  and Italy. e price ncreases ll educe o Th i wi r the  French  surplus  o  near  zero. taly's  all  deficit   1973 t I sm in was  expected  to  narrow further  ut  should  now  be in the b $1.5 billion-S2  illion  ange. b r
# Some  of  the impact  of  higher  oil rices n the consuming countries p i will  be offset y  greater epatriation    oil  company  profits  nd larger b r of a exports  to  the  producers,  enerated y their  reater xport  income.  Only g b g e part  of the  worldwide producer  revenue increases f o $15 billion  ill  be w spent, owever.  The 1974 oil  revenues  of  Saudi  Arabia, bu  Dhabi,  Qatar, h A and Kuwait will  approach  the  amounts  recently  stimated  or  1980.  These e f countries  ave only limited bsorptive apacities. h a c
# Although the trade  balances  of the oil  importers ill deteriorate w sharply, he  impact on their omestic  economies will  probably  be slight. t d Oil imports  do not  compete with  domestic  production  o there hould  be s s no initial fsetting ss  in  jobs. he consuming countries' n-petroleum of lo T no trade  and production ill  essentially   the  same  as  before  the oil  price w be
# 5
# increase.  oreover,  the  sharp  rise n crude  oil rices  hould  not  significantly M i p s increase he price  of  finished oods. t g
# The use to  which the  oil  producers ut  their  eserves ould  have an p r c appreciable  mpact  on the  international hange  rate ystem  and,  through i exc s the  exchange system,ultimately    the  volume  of  exports nd imports. on a If,  or xample,  the  producers  ecide  to-hold  ost of heir  ncreased  eceipts f e d m t i r in  dollars, he dollar  will strengthen  in exchange  markets.  A t dollar appreciation  eans more expensive m -and therefore  educed r -US exports. In effect,  he oil  producers  will  be converting heir  rade  surpluses  ith t t t w other  consumers  into rade urpluses  ith  the  United  States;  r, n  another t s w o i view,  the  US  trade  account  with Japan,  Canada, and Western Europe will deteriorate   the  amount 'of he  increase n their il  import  bills. by t i o
# As the  oil roducers'  eserves  ncrease,  heir  hreat  o  exchange  markets p r i t t t will  also  increase.  he Arab oil  states  lready ave enough liquid oreign T a h f assets -around SS-S7  billion    to  temporarily  isrupt  urrency  markets. ' d c Although there  is  no  evid'ence f  any substantial llar ales  during  the o do s current risis, d an attack  n the  dollar  ould result  the  depreciation c an o w in of the  Arabs'  own reserve  holding, t  is not  inconceivable  hat i t -if  the political  d  military  ituation  comes increasingly acceptable  o  them an s be un t -the Arab leadership  ould move  against  the  dollar.  n  Thursday,  Libya w O publicly  called for  concerted rab dollar ales  and  withdrawal f  deposits A s o from US  banks.
# 6

# %% [markdown]
# ### RAG chain setup

# %%
def create_rag_chain(retriever):
    prompt = """
        You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question.
        If you don't know the answer, just say that you don't know.
        Answer in bullet points. Make sure your answer is relevant to the question and it is answered from the context only.
        ### Question: {question} 
        
        ### Context: {context} 
        
        ### Answer:
    """
    model = ChatOllama(model="deepseek-r1:8b", base_url="http://localhost:11434")
    prompt_template = ChatPromptTemplate.from_template(prompt)

    chain = (
        {"context": retriever | format_docs, "question": RunnablePassthrough()}
        | prompt_template
        | model
        | StrOutputParser()
    )
    return chain

# %% [markdown]
# ### Piecing together everything

# %%
# One-time process

# Load document
source = "./data/input/document_1.pdf"
markdown_content = load_and_convert_document(source)
chunks = get_markdown_splits(markdown_content)

# Create vector store
vector_store = setup_vector_store(chunks)

# Setup retriever
retriever = vector_store.as_retriever(search_type="mmr", search_kwargs={'k': 3})

# Create RAG chain
rag_chain = create_rag_chain(retriever)

# %% [markdown]
# ### Retrieval

# %%
#Questions here

question = "What were 5 effects of the arabic oil cutback and higher prices?"

print(f"Question: {question}")
for chunk in rag_chain.stream(question):
    print(chunk, end="", flush=True)
print("\n" + "-" * 50 + "\n")
# Out:
# Question: What were 5 effects of the arabic oil cutback and higher prices?
# <think>
# Okay, I need to figure out the five effects of the Arab oil cutback and higher prices based on the given context. Let me read through the context carefully.
#
# First, the context talks about a 5% production cutback by Arab countries and how that affects oil import bills for the US, Japan, and Western Europe. It mentions specific increases in billions for each: the US around $3 billion trade surplus turning into a deficit, Japan's surplus going down from $6 to $3 billion, West Germans paying an extra $1.8 billion but still having a significant trade surplus, UK's trade deficit increasing from $3.5 to almost $5 billion, and France and Italy seeing their deficits also increase.
#
# So the first effect is that oil import bills for these countries rise significantly. That seems straightforward.
#
# Next, it mentions that some impacts of higher oil prices will be offset by increased repatriation of oil company profits and larger exports from producers. This means companies might bring more money back to their home countries, which could help balance out the trade deficits a bit. But only part of the $15 billion increase in producer revenues is spent, so most remains with the producers.
#
# Third effect: Higher oil prices lead to increased production revenue for oil-producing Arab states like Saudi Arabia and others. Their 1974 revenues approach the levels expected in 1980. However, they have limited absorptive capacity, meaning they might not be able to use all that money effectively.
#
# Fourth effect is about trade balances. While consuming countries' trade balances deteriorate, their domestic economies probably aren't severely affected because oil imports don't compete with domestic production much. So initially, jobs and production remain similar as before the price hike.
#
# Fifth, the context discusses how oil producers might hold onto their increased receipts in dollars. This would strengthen the dollar in exchange markets, making US exports more expensive, thus decreasing them. This converts the producers' trade surpluses with other consumers (like Japan, Canada, etc.) into surpluses with the US. So the US's trade account with these countries would deteriorate as their import bills go up.
#
# Wait, let me check if I have five effects. The context mentions five points: increased oil import bills, offsetting by repatriation and exports, higher revenues for producers, slight impact on domestic economies, and exchange market effects leading to trade balance shifts.
#
# I think that's it.
# </think>
#
# - **Increased Oil Import Bills**: Oil import bills for the US, Japan, and Western Europe rise significantly.
# - **Offsetting Effects from Repatriation and Exports**: Greater repatriation of oil company profits and increased exports from producers help mitigate some impacts.
# - **Higher Revenues for Producers**: Arab oil states see significant revenue increases, approaching levels expected in 1980.
# - **Minimal Impact on Domestic Economies**: Consuming countries' economies are mostly unaffected initially due to limited competition with domestic production.
# - **Exchange Market Effects and Trade Balances**: Oil producers holding increased dollars strengthen the dollar, reducing US exports and worsening trade accounts with Japan, Canada, and Western Europe.
# --------------------------------------------------
